# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # СЧИТЫВАЕМ данные

# %%
# orders_xlsx = pd.read_excel('/Users/vladislavlipkin/Documents/PycharmProjects/Simulate/final_python_samokat/data/orders.xlsx') # MACOS
orders_xlsx = pd.read_excel(r'C:\Users\Incognitus\Documents\git_hub\Simulate\final_python_samokat\data\orders.xlsx') # WIN

# %%
# products_xlsx = pd.read_excel('/Users/vladislavlipkin/Documents/PycharmProjects/Simulate/final_python_samokat/data/products.xlsx') # MACOS
products_xlsx = pd.read_excel(r'C:\Users\Incognitus\Documents\git_hub\Simulate\final_python_samokat\data\products.xlsx') # WIN

# %% [markdown]
# # и что же там ?

# %%
orders_xlsx.head(5)
# Out:
#      order_id         accepted_at  product_id  quantity  regular_price  price  \
# 0  1517514900 2022-01-13 16:48:19       17122         1            169    169
# 1  1517430051 2022-01-13 16:46:53       17122         1            169    169
# 2  1517578174 2022-01-13 18:12:30       17122         1            169    169
# 3  1517466327 2022-01-13 15:11:12       22199         1            219    219
# 4  1517429157 2022-01-13 19:15:59       22199         1            219    219
#
#    cost_price
# 0          74
# 1          74
# 2          74
# 3         130
# 4         130

# %%
products_xlsx.head(5)
# Out:
#    product_id                       level1                       level2  \
# 0           1                      Гигиена                       Бритье
# 1           2  Мучные кондитерские изделия  Мучные кондитерские изделия
# 2           3           Мясная гастрономия           Сосиски, сардельки
# 3           4                          Чай                   Черный чай
# 4           5       Безалкогольные напитки            Соковая продукция
#
#                                                 name
# 0  Кассеты для бритья Gillette Fusion ProGlide Po...
# 1                                  Печенье Бодрость
# 2                               Сосиски Стародворье
# 3                                       Чай Азерчай
# 4                                        Морс Valio

# %% [markdown]
# # Описание таблиц
#
# ## Таблица products
#
# | Колонка       | Описание                    |
# |---------------|-----------------------------|
# | product_id    | id товара                   |
# | level1        | категория                   |
# | level2        | подкатегория                |
# | name          | наименование товара         |
#
# ## Таблица orders
#
# | Колонка        | Описание                         |
# |----------------|----------------------------------|
# | order_id       | номер чека                       |
# | accepted_at    | дата и время чека                |
# | product_id     | id товара                        |
# | quantity       | кол-во товара в чеке             |
# | regular_price  | регулярная цена                  |
# | price          | текущая цена                     |
# | cost_price     | закупочная цена                  |

# %% [markdown]
# # TASKS

# %% [markdown]
# # 1. Самая ходовая товарная группа
#
# ## Задание
# По какой категории товаров продано больше всего позиций?
#
# ## Требования
# 1. Подкрепите ответ таблицей, в которой рассчитано количество проданных штук товара в каждой товарной категории.
# 2. Дополнительно постройте на основании этой таблицы barchart.
# 3. Проверьте, чтобы все подписи на графике выглядели читаемо и понятно.
# 4. График должен быть сходу понятен стороннему наблюдателю.

# %%
merge_table = pd.merge(
    orders_xlsx
    , products_xlsx
    , on='product_id'
    , how='left'
)

# %%
merge_table.head(3)
# Out:
#      order_id         accepted_at  product_id  quantity  regular_price  price  \
# 0  1517514900 2022-01-13 16:48:19       17122         1            169    169
# 1  1517430051 2022-01-13 16:46:53       17122         1            169    169
# 2  1517578174 2022-01-13 18:12:30       17122         1            169    169
#
#    cost_price              level1                  level2  \
# 0          74  Рыбная гастрономия  Нерыбные продукты моря
# 1          74  Рыбная гастрономия  Нерыбные продукты моря
# 2          74  Рыбная гастрономия  Нерыбные продукты моря
#
#                          name
# 0  Крабовые палочки Меридиан
# 1  Крабовые палочки Меридиан
# 2  Крабовые палочки Меридиан

# %%
agg_count_category = merge_table.groupby('level1').agg(
    quantity_of_products = ('quantity', 'sum')
).reset_index()

result_quantity_of_products = agg_count_category.sort_values('quantity_of_products', ascending=False).reset_index().head(5)
result_quantity_of_products
# Out:
#    index                  level1  quantity_of_products
# 0      1  Безалкогольные напитки                   534
# 1     11      Молочная продукция                   483
# 2     19            Свежие овощи                   262
# 3     10               Кулинария                   250
# 4      0                 Бакалея                   239

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))
sns.barplot(x='level1', y='quantity_of_products', data=result_quantity_of_products, palette='viridis')
plt.xlabel('Категория товаров', fontsize=12)
plt.ylabel('Количество проданных позиций', fontsize=12)
plt.title('(ТОП 5) Продажи по категориям товаров', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Распределение продаж по подкатегориям
#
# ## Задание
# Оцените распределение количества проданных позиций в каждой товарной категории (level1) по подкатегориям (level2). Проиллюстрируйте свой результат расчетной таблицей.

# %%
merge_table.head(1)
# Out:
#      order_id         accepted_at  product_id  quantity  regular_price  price  \
# 0  1517514900 2022-01-13 16:48:19       17122         1            169    169
#
#    cost_price              level1                  level2  \
# 0          74  Рыбная гастрономия  Нерыбные продукты моря
#
#                          name
# 0  Крабовые палочки Меридиан

# %%
agg_count_subcategory = merge_table.groupby(['level1', 'level2']).agg(
    quantity_of_subcategory = ('quantity', 'sum')
).reset_index()

result_quantity_of_subcategory = agg_count_subcategory.sort_values(
    ['quantity_of_subcategory'], 
    ascending=[False]
).reset_index(drop=True)

result_quantity_of_subcategory.head(10)
# Out:
#                          level1                                 level2  \
# 0        Безалкогольные напитки                                Напитки
# 1                     Кулинария                          Готовые блюда
# 2  Хлеб и хлебобулочные изделия           Хлеб и хлебобулочные изделия
# 3                         Снэки                          Снэки соленые
# 4        Безалкогольные напитки                          Воды питьевые
# 5                  Свежие овощи      Корнеплоды, зелень и прочие овощи
# 6            Молочная продукция                        Молоко и сливки
# 7            Молочная продукция             Молочно-десертные продукты
# 8                 Свежие фрукты  Цитрусовые, семечковые и прочие плоды
# 9            Молочная продукция    Кисломолочные традиционные продукты
#
#    quantity_of_subcategory
# 0                      252
# 1                      248
# 2                      218
# 3                      180
# 4                      162
# ...

# %% [markdown]
# # Найти средний чек в заданную дату
#
# ## Задание
# Какой средний чек был 13.01.2022?

# %%
# создадим столбец с датой , и приведем в строку
merge_table['date'] = merge_table['accepted_at'].dt.date.astype(str)
# сделаем общую сумму по чеку с учетом количества
merge_table['total_price'] = merge_table['price'] * merge_table['quantity']
merge_table.head(3)
# Out:
#      order_id         accepted_at  product_id  quantity  regular_price  price  \
# 0  1517514900 2022-01-13 16:48:19       17122         1            169    169
# 1  1517430051 2022-01-13 16:46:53       17122         1            169    169
# 2  1517578174 2022-01-13 18:12:30       17122         1            169    169
#
#    cost_price              level1                  level2  \
# 0          74  Рыбная гастрономия  Нерыбные продукты моря
# 1          74  Рыбная гастрономия  Нерыбные продукты моря
# 2          74  Рыбная гастрономия  Нерыбные продукты моря
#
#                          name        date  total_price
# 0  Крабовые палочки Меридиан   2022-01-13          169
# 1  Крабовые палочки Меридиан   2022-01-13          169
# 2  Крабовые палочки Меридиан   2022-01-13          169

# %%
filter_time = '2022-01-13'
jan13_avg_check = merge_table.query('date == @filter_time')

# %%
print(f'средний чек по заданой дате {filter_time}: -- {round(jan13_avg_check['total_price'].mean(), 2)} --')
# Out:
# средний чек по заданой дате 2022-01-13: -- 149.9 --

# %% [markdown]
# # Доля промо в заданной категории
#
# ## Описание задачи
# Когда товар продается по промо-акции, его базовая цена не совпадает с фактической ценой.
#
# ## Задание
# 1. Посчитать, какую долю от общих продаж категории **Сыры** занимают промо (в штуках)
# 2. Построить пайчарт, который это проиллюстрирует
# 3. На графике должны быть видны группы, соответствующие доли и понятные подписи к ним

# %%
cheese_filter = 'Сыры'
cheese_table = merge_table.query('level1 == @cheese_filter')
cheese_table.head(3)
# Out:
#      order_id         accepted_at  product_id  quantity  regular_price  price  \
# 3  1517466327 2022-01-13 15:11:12       22199         1            219    219
# 4  1517429157 2022-01-13 19:15:59       22199         1            219    219
# 5  1517416615 2022-01-13 10:39:06       22199         1            219    219
#
#    cost_price level1       level2          name        date  total_price
# 3         130   Сыры  Мягкие сыры  Сыр Самокат   2022-01-13          219
# 4         130   Сыры  Мягкие сыры  Сыр Самокат   2022-01-13          219
# 5         130   Сыры  Мягкие сыры  Сыр Самокат   2022-01-13          219

# %%
promo_cheese = cheese_table.query('regular_price != price')
promo_cheese.head(3)
# Out:
#        order_id         accepted_at  product_id  quantity  regular_price  \
# 121  1517667466 2022-01-13 15:28:48        9385         2            152
# 122  1517632967 2022-01-13 19:05:35        9385         1            152
# 123  1517503071 2022-01-13 13:37:17        9385         1            152
#
#      price  cost_price level1                 level2                 name  \
# 121    129          77   Сыры  Твердые сычужные сыры  Сыр Cheese Gallery
# 122    129          77   Сыры  Твердые сычужные сыры  Сыр Cheese Gallery
# 123    129          77   Сыры  Твердые сычужные сыры  Сыр Cheese Gallery
#
#            date  total_price
# 121  2022-01-13          258
# 122  2022-01-13          129
# 123  2022-01-13          129

# %%
result_share = promo_cheese['quantity'].sum() / cheese_table['quantity'].sum() * 100.0
result_share
# Out:
# np.float64(30.701754385964914)

# %%
promo_qty = promo_cheese['quantity'].sum()
non_promo_qty = cheese_table['quantity'].sum() - promo_qty

plt.figure(figsize=(6,6))
plt.pie([promo_qty, non_promo_qty], 
        labels=['Промо', 'Не промо'], 
        autopct='%1.1f%%', 
        colors=['#ff9999', '#66b3ff'])
plt.title('Доля промо-продаж в категории "Сыры" (в штуках)')
plt.show()

# %% [markdown]
# # Посчитать маржу по категориям
#
# Нужно посчитать маржу:
#
# - В рублях
# - В %
#
# Сделать это нужно по всем категориям level1 и отобразить с помощью 2 горизонтальных барчартов. Все подписи должны быть читаемыми и понятными.

# %%
merge_table.head(3)
# Out:
#      order_id         accepted_at  product_id  quantity  regular_price  price  \
# 0  1517514900 2022-01-13 16:48:19       17122         1            169    169
# 1  1517430051 2022-01-13 16:46:53       17122         1            169    169
# 2  1517578174 2022-01-13 18:12:30       17122         1            169    169
#
#    cost_price              level1                  level2  \
# 0          74  Рыбная гастрономия  Нерыбные продукты моря
# 1          74  Рыбная гастрономия  Нерыбные продукты моря
# 2          74  Рыбная гастрономия  Нерыбные продукты моря
#
#                          name        date  total_price
# 0  Крабовые палочки Меридиан   2022-01-13          169
# 1  Крабовые палочки Меридиан   2022-01-13          169
# 2  Крабовые палочки Меридиан   2022-01-13          169

# %%
merge_table['cost_total_price'] = merge_table['cost_price'] * merge_table['quantity']
merge_table.head(3)
# Out:
#      order_id         accepted_at  product_id  quantity  regular_price  price  \
# 0  1517514900 2022-01-13 16:48:19       17122         1            169    169
# 1  1517430051 2022-01-13 16:46:53       17122         1            169    169
# 2  1517578174 2022-01-13 18:12:30       17122         1            169    169
#
#    cost_price              level1                  level2  \
# 0          74  Рыбная гастрономия  Нерыбные продукты моря
# 1          74  Рыбная гастрономия  Нерыбные продукты моря
# 2          74  Рыбная гастрономия  Нерыбные продукты моря
#
#                          name        date  total_price  cost_total_price
# 0  Крабовые палочки Меридиан   2022-01-13          169                74
# 1  Крабовые палочки Меридиан   2022-01-13          169                74
# 2  Крабовые палочки Меридиан   2022-01-13          169                74

# %%
print(f'ALL REVENUE {merge_table['total_price'].sum()}')
print(f'COST ALL REVENUE {merge_table['cost_total_price'].sum()}')
# Out:
# ALL REVENUE 498107
# COST ALL REVENUE 308625

# %%
merge_table['percent_marginality'] = (merge_table['total_price'] - merge_table['cost_total_price']) / merge_table['total_price'] * 100.0
result_margin_by_category = merge_table.groupby('level1').agg(
    percent_margin_by_category = ('percent_marginality', 'sum')
).reset_index()
result_margin_by_category
# Out:
#                           level1  percent_margin_by_category
# 0                        Бакалея                 6867.320545
# 1         Безалкогольные напитки                16016.493961
# 2                  Бытовая химия                  576.845377
# 3                        Гигиена                 2044.968696
# 4                Детское питание                 2168.661736
# 5       Детство (Гигиена и Уход)                  197.358012
# 6         Замороженная продукция                 6607.830143
# 7           Кондитерские изделия                 4379.659311
# 8      Консервированные продукты                 2524.422713
# 9                    Кофе, какао                  720.445005
# 10                     Кулинария                10114.807481
# 11            Молочная продукция                10743.350893
# 12   Мучные кондитерские изделия                 4680.461438
# 13            Мясная гастрономия                 3893.473700
# ...
