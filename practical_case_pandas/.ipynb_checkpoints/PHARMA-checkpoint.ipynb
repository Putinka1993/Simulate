# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # загружаем входящую ВЫГРУЗКУ из СБИС

# %%
inbox_1 = pd.read_csv(r'C:\Users\Incognitus\Documents\git_hub\Simulate\practical_case_pandas\Входящие\Входящие 01.csv', sep=';', encoding='cp1251')

# %%
inbox_2 = pd.read_csv(r'C:\Users\Incognitus\Documents\git_hub\Simulate\practical_case_pandas\Входящие\Входящие 02.csv', sep=';', encoding='cp1251')

# %%
inbox_3 = pd.read_csv(r'C:\Users\Incognitus\Documents\git_hub\Simulate\practical_case_pandas\Входящие\Входящие 03.csv', sep=';', encoding='cp1251')

# %%
inbox_1.head(1)
# Out:
#        Дата        Номер     Сумма                        Статус  Примечание  \
# 0  30.09.21  БРН00709545  4 056,46  Выполнение завершено успешно         NaN
#
#                        Комментарий         Контрагент                 ИНН/КПП  \
# 0  БРН00709545 на сумму 4 056,46р.  Пульс Брянск, ООО  3255510243 / 325701001
#
#          Организация               ИНН/КПП.1  ...     Время Тип пакета  \
# 0  ООО Рога и Копыта  4025419873 / 402501001  ...  23:40:56  ДокОтгрВх
#
#                    Идентификатор пакета Запущено в обработку  \
# 0  76210df0-7c48-4e6d-ad2b-6cbe2f3b7722       30.09.21 23:40
#
#   Получено контрагентом       Завершено  Увеличение суммы   НДС  \
# 0        01.10.21 08:39  01.10.21 14:59              0,00  0,00
#
#    Уменьшение суммы НДС.1
# 0              0,00  0,00
#
# [1 rows x 30 columns]

# %%
inbox_2.head(1)
# Out:
#        Дата        Номер   Сумма                        Статус  Примечание  \
# 0  09.12.20  10324858-30  417,34  Выполнение завершено успешно         NaN
#
#                                          Комментарий  \
# 0  Интернет заказ: MA-18962181; Интернет заказ: M...
#
#                           Контрагент                 ИНН/КПП  \
# 0  Филиал АО НПК "Катрен" в г. Химки  5408130693 / 504743001
#
#          Организация               ИНН/КПП.1  ...     Время Тип пакета  \
# 0  ООО Рога и Копыта  4025419873 / 402501001  ...  11:05:06  ДокОтгрВх
#
#                    Идентификатор пакета Запущено в обработку  \
# 0  90e7b521-7842-42a7-a55f-876cf0aec0e1                  NaN
#
#   Получено контрагентом Завершено  Увеличение суммы   НДС  Уменьшение суммы  \
# 0                   NaN       NaN              0,00  0,00              0,00
#
#   НДС.1
# 0  0,00
#
# [1 rows x 30 columns]

# %%
inbox_3.head(1)
# Out:
#        Дата       Номер Сумма                        Статус  Примечание  \
# 0  13.12.19  8059548-30  0,00  Выполнение завершено успешно         NaN
#
#                                          Комментарий  \
# 0  Интернет заказ: A-41612340; Интернет заказ: A-...
#
#                           Контрагент                 ИНН/КПП  \
# 0  Филиал АО НПК "Катрен" в г. Химки  5408130693 / 504743001
#
#          Организация               ИНН/КПП.1  ...     Время Тип пакета  \
# 0  ООО Рога и Копыта  4025419873 / 402501001  ...  18:06:10  ДокОтгрВх
#
#                    Идентификатор пакета Запущено в обработку  \
# 0  287f2f6d-cef7-418a-b4a4-282de14a5141                  NaN
#
#   Получено контрагентом Завершено  Увеличение суммы   НДС  Уменьшение суммы  \
# 0                   NaN       NaN              0,00  0,00              0,00
#
#   НДС.1
# 0  0,00
#
# [1 rows x 30 columns]

# %%
# проверим на совпадение имен в столбцах.
print(all(inbox_1.columns == inbox_2.columns) and all(inbox_2.columns == inbox_3.columns))
# Out:
# True

# %%
new_rename_columns = [
    "Дата",
    "Номер",
    "Сумма",
    "Статус",
    "Примечание",
    "Комментарий",
    "Контрагент",
    "ИНН/КПП",
    "Организация",
    "ИНН/КПП",
    "Тип_документа",
    "Имя_файла",
    "Дата",
    "Номер_1",
    "Сумма_1",
    "Сумма_НДС",
    "Ответственный",
    "Подразделение",
    "Код",
    "Дата",
    "Время",
    "Тип_пакета",
    "Идентификатор_пакета",
    "Запущено_в_обработку",
    "Получено_контрагентом",
    "Завершено",
    "Увеличение_суммы",
    "НДC",
    "Уменьшение_суммы",
    "НДС"
                 ]

# %%
# проверим длину всех входящих боксов
print(len(inbox_1))
print(len(inbox_2))
print(len(inbox_3))
# Out:
# 100000
# 100000
# 95737

# %%
# объеденим все боксы
df_total_inbox = pd.concat([inbox_1, inbox_2, inbox_3], ignore_index=True)

# %%
# проверим длину общего массива данных.
print(len(df_total_inbox))
# Out:
# 295737

# %%
df_total_inbox.columns = new_rename_columns

# %%
df_total_inbox.head(2)
# Out:
#        Дата        Номер     Сумма                        Статус  Примечание  \
# 0  30.09.21  БРН00709545  4 056,46  Выполнение завершено успешно         NaN
# 1  30.09.21  БРН00709545  4 056,46  Выполнение завершено успешно         NaN
#
#                        Комментарий         Контрагент                 ИНН/КПП  \
# 0  БРН00709545 на сумму 4 056,46р.  Пульс Брянск, ООО  3255510243 / 325701001
# 1  БРН00709545 на сумму 4 056,46р.  Пульс Брянск, ООО  3255510243 / 325701001
#
#          Организация                 ИНН/КПП  ...     Время Тип_пакета  \
# 0  ООО Рога и Копыта  4025419873 / 402501001  ...  23:40:56  ДокОтгрВх
# 1  ООО Рога и Копыта  4025419873 / 402501001  ...  23:40:56  ДокОтгрВх
#
#                    Идентификатор_пакета Запущено_в_обработку  \
# 0  76210df0-7c48-4e6d-ad2b-6cbe2f3b7722       30.09.21 23:40
# 1  76210df0-7c48-4e6d-ad2b-6cbe2f3b7722                  NaN
#
#   Получено_контрагентом       Завершено  Увеличение_суммы   НДC  \
# ...

# %% [markdown]
# # загружаем Аптеки

# %%
pharmacy_366 = pd.read_csv(r'C:\Users\Incognitus\Documents\git_hub\Simulate\practical_case_pandas\Аптеки\csv\correct\366.csv', sep=';', encoding='cp1251')

# %%
pharmacy_A123 = pd.read_csv(r'C:\Users\Incognitus\Documents\git_hub\Simulate\practical_case_pandas\Аптеки\csv\correct\А123.csv', sep=';', encoding='cp1251')

# %%
pharmacy_366.head(2)
# Out:
#    № п/п  Штрих-код партии                                Наименование товара  \
# 0      1      200200060311  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. Р.S №100 (50П...
# 1      2      200801594420  КОСМОПОР ПОВЯЗКА 10СМХ6СМ №25 П/ОПЕР. САМОКЛ. ...
#
#         Поставщик Дата приходного документа  Номер приходного документа  \
# 0  Катрен г.Химки                26.05.2021                   2002088.0
# 1     Здравсервис                25.03.2020                   9000479.8
#
#   Дата накладной    Номер накладной  Кол-во  Сумма в закупочных ценах без НДС  \
# 0     25.05.2021         4665120-30    0.04                             33.65
# 1     25.03.2020  E7914339/27806739    0.04                             27.58
#
#   Ставка НДС поставщика  Сумма НДС  Сумма в закупочных ценах с НДС
# 0                   10%       3.37                           37.02
# 1                   10%       2.76                           30.34

# %%
pharmacy_366.columns
# Out:
# Index(['№ п/п', 'Штрих-код партии', 'Наименование товара', 'Поставщик',
#        'Дата приходного документа', 'Номер приходного документа',
#        'Дата накладной', 'Номер накладной', 'Кол-во',
#        'Сумма в закупочных ценах без НДС', 'Ставка НДС поставщика',
#        'Сумма НДС', 'Сумма в закупочных ценах с НДС'],
#       dtype='object')

# %%
pharmacy_A123.head(2)
# Out:
#    № п/п  Штрих-код партии                                Наименование товара  \
# 0      1      201300039533  СФМ ПЕРЧАТКИ СМОТР. ГОЛУБЫЕ Н/СТЕР. НИТРИЛ Р.L...
# 1      2      201300052321  ХАРТМАНН КОСМОПОР Е ПОВЯЗКА 15СМХ8СМ №25 П/ОПЕ...
#
#           Поставщик Дата приходного документа  Номер приходного документа  \
# 0    Катрен г.Химки                19.04.2021                  13001265.0
# 1  Фармкомплект ООО                17.08.2021                  13002787.0
#
#   Дата накладной Номер накладной  Кол-во  Сумма в закупочных ценах без НДС  \
# 0     18.04.2021      3541290-30    0.02                             36.48
# 1     16.08.2021     ФК003216604    0.04                             18.43
#
#   Ставка НДС поставщика  Сумма НДС  Сумма в закупочных ценах с НДС
# 0                   10%       3.65                           40.13
# 1                   10%       1.84                           20.28

# %%
pharmacy_A123.columns
# Out:
# Index(['№ п/п', 'Штрих-код партии', 'Наименование товара', 'Поставщик',
#        'Дата приходного документа', 'Номер приходного документа',
#        'Дата накладной', 'Номер накладной', 'Кол-во',
#        'Сумма в закупочных ценах без НДС', 'Ставка НДС поставщика',
#        'Сумма НДС', 'Сумма в закупочных ценах с НДС'],
#       dtype='object')

# %%
pharmacy_366.columns == pharmacy_A123.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
# объеденим все боксы
df_total_pharmacy = pd.concat([pharmacy_366, pharmacy_A123], ignore_index=True)

# %%
df_total_pharmacy.head(3)
# Out:
#    № п/п  Штрих-код партии                                Наименование товара  \
# 0      1      200200060311  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. Р.S №100 (50П...
# 1      2      200801594420  КОСМОПОР ПОВЯЗКА 10СМХ6СМ №25 П/ОПЕР. САМОКЛ. ...
# 2      3      200200075091  ХАРТМАНН БРАНОЛИНД H ПОВЯЗКА СТЕР. 10Х20СМ. №3...
#
#         Поставщик Дата приходного документа  Номер приходного документа  \
# 0  Катрен г.Химки                26.05.2021                   2002088.0
# 1     Здравсервис                25.03.2020                   9000479.8
# 2          Протек                01.09.2021                   2003451.0
#
#   Дата накладной    Номер накладной    Кол-во  \
# 0     25.05.2021         4665120-30  0.040000
# 1     25.03.2020  E7914339/27806739  0.040000
# 2     01.09.2021      164621235-001  0.066667
#
#    Сумма в закупочных ценах без НДС Ставка НДС поставщика  Сумма НДС  \
# 0                             33.65                   10%       3.37
# ...

# %%
df_total_pharmacy["Номер счет-фактуры"] = None
df_total_pharmacy["Сумма счет-фактуры"] = None
df_total_pharmacy["Дата счет-фактуры"] = None
df_total_pharmacy["Сравнение дат"] = None

# %%
target = 'ЕАПТЕКА'

mask = df_total_pharmacy['Поставщик'].str.contains(target, case=False, na=False)

df_total_pharmacy['Номер накладной'] = np.where(mask, 
                                                 df_total_pharmacy['Номер накладной'] + '/15', 
                                                 df_total_pharmacy['Номер накладной'])

# %%
# target = 'ЕАПТЕКА'
# df_total_pharmacy.query('Поставщик.str.contains(@target, case=False, na=False)').head(2)

# %%
df_total_pharmacy.head(2)
# Out:
#    № п/п  Штрих-код партии                                Наименование товара  \
# 0      1      200200060311  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. Р.S №100 (50П...
# 1      2      200801594420  КОСМОПОР ПОВЯЗКА 10СМХ6СМ №25 П/ОПЕР. САМОКЛ. ...
#
#         Поставщик Дата приходного документа  Номер приходного документа  \
# 0  Катрен г.Химки                26.05.2021                   2002088.0
# 1     Здравсервис                25.03.2020                   9000479.8
#
#   Дата накладной    Номер накладной  Кол-во  Сумма в закупочных ценах без НДС  \
# 0     25.05.2021         4665120-30    0.04                             33.65
# 1     25.03.2020  E7914339/27806739    0.04                             27.58
#
#   Ставка НДС поставщика  Сумма НДС  Сумма в закупочных ценах с НДС  \
# 0                   10%       3.37                           37.02
# 1                   10%       2.76                           30.34
#
# ...

# %%
df_total_inbox = df_total_inbox.loc[:, ~df_total_inbox.columns.duplicated()]
df_total_inbox.head(2)
# Out:
#        Дата        Номер     Сумма                        Статус  Примечание  \
# 0  30.09.21  БРН00709545  4 056,46  Выполнение завершено успешно         NaN
# 1  30.09.21  БРН00709545  4 056,46  Выполнение завершено успешно         NaN
#
#                        Комментарий         Контрагент                 ИНН/КПП  \
# 0  БРН00709545 на сумму 4 056,46р.  Пульс Брянск, ООО  3255510243 / 325701001
# 1  БРН00709545 на сумму 4 056,46р.  Пульс Брянск, ООО  3255510243 / 325701001
#
#          Организация Тип_документа  ...     Время Тип_пакета  \
# 0  ООО Рога и Копыта       ЭДОНакл  ...  23:40:56  ДокОтгрВх
# 1  ООО Рога и Копыта        СчФктр  ...  23:40:56  ДокОтгрВх
#
#                    Идентификатор_пакета Запущено_в_обработку  \
# 0  76210df0-7c48-4e6d-ad2b-6cbe2f3b7722       30.09.21 23:40
# 1  76210df0-7c48-4e6d-ad2b-6cbe2f3b7722                  NaN
#
#    Получено_контрагентом       Завершено  Увеличение_суммы   НДC  \
# ...

# %%
# Из найденных строк нужно оставить только те, которые имеют один из типов документа: ["СчФктр", "УпдДоп", "УпдСчфДоп", "ЭДОНакл"]

# %%
df_total_pharmacy.columns = ['№_п/п', 'Штрих-код_партии', 'Наименование_товара', 'Поставщик',
       'Дата_приходного_документа', 'Номер_приходного_документа',
       'Дата_накладной', 'Номер_накладной', 'Кол-во',
       'Сумма_в_закупочных_ценах_без_НДС', 'Ставка_НДС_поставщика',
       'Сумма_НДС', 'Сумма_в_закупочных_ценах_с_НДС', 'Номер_счет-фактуры',
       'Сумма_счет-фактуры', 'Дата_счет-фактуры', 'Сравнение_дат']

# %%
target_columns_type_doc = ["СчФктр", "УпдДоп", "УпдСчфДоп", "ЭДОНакл"]
df_total_inbox_filter = df_total_inbox.query('Тип_документа in @target_columns_type_doc')

target_columns_no = df_total_inbox_filter['Номер'].to_list()
df_total_pharmacy_filter = df_total_pharmacy.query('Номер_накладной in @target_columns_no')

# %%
df_total_pharmacy_filter.head(2)
# Out:
#    №_п/п  Штрих-код_партии                                Наименование_товара  \
# 0      1      200200060311  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. Р.S №100 (50П...
# 1      2      200801594420  КОСМОПОР ПОВЯЗКА 10СМХ6СМ №25 П/ОПЕР. САМОКЛ. ...
#
#         Поставщик Дата_приходного_документа  Номер_приходного_документа  \
# 0  Катрен г.Химки                26.05.2021                   2002088.0
# 1     Здравсервис                25.03.2020                   9000479.8
#
#   Дата_накладной    Номер_накладной  Кол-во  Сумма_в_закупочных_ценах_без_НДС  \
# 0     25.05.2021         4665120-30    0.04                             33.65
# 1     25.03.2020  E7914339/27806739    0.04                             27.58
#
#   Ставка_НДС_поставщика  Сумма_НДС  Сумма_в_закупочных_ценах_с_НДС  \
# 0                   10%       3.37                           37.02
# 1                   10%       2.76                           30.34
#
# ...

# %%
#OK Если "Поставщик" - ЕАПТЕКА, то к "Номер накладной" нужно добавить /15.
#OK Нужно найти все записи в выгрузке из СБИСа по данному номеру накладной
#OK Из найденных строк нужно оставить только те, которые имеют один из типов документа: ["СчФктр", "УпдДоп", "УпдСчфДоп", "ЭДОНакл"]
#OK Если ничего не найдено - просто переходим к следующей строке
#? Если найдено - нужно сохранить значения Номер, Сумма и Дата
#? Дату нужно представить в формате 25.05.2021
# В столбцы из пункта 5 нужно записать найденные для данной строки значения
# В столбец Сравнение дат помещаем "Не совпадает!", если найденная дата и дата накладной отличаются. Иначе - пустая строка.
# Обратите внимание: если по заданным условиям находится несколько подходящих документов - выбираем значения из первого найденного. Это означает, что если у документов разные суммы, берется та, что стоит первой в выгрузке из СБИС.

# Если дата счет фактуры отсутствует или пуста, а дата накладной заполнена, такая ситуация считается расхождением.

# %%
df_total_pharmacy_filter.columns
# Out:
# Index(['№_п/п', 'Штрих-код_партии', 'Наименование_товара', 'Поставщик',
#        'Дата_приходного_документа', 'Номер_приходного_документа',
#        'Дата_накладной', 'Номер_накладной', 'Кол-во',
#        'Сумма_в_закупочных_ценах_без_НДС', 'Ставка_НДС_поставщика',
#        'Сумма_НДС', 'Сумма_в_закупочных_ценах_с_НДС', 'Номер_счет-фактуры',
#        'Сумма_счет-фактуры', 'Дата_счет-фактуры', 'Сравнение_дат'],
#       dtype='object')

# %%
df_total_pharmacy_filter['Номер_счет-фактуры'] = df_total_pharmacy_filter['Номер_накладной']
df_total_pharmacy_filter['Сумма_счет-фактуры'] = df_total_pharmacy_filter['Сумма_НДС']
df_total_pharmacy_filter['Дата_счет-фактуры'] = df_total_pharmacy_filter['Дата_накладной']
# Out:
# C:\Users\Incognitus\AppData\Local\Temp\ipykernel_2652\665107074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_pharmacy_filter['Номер_счет-фактуры'] = df_total_pharmacy_filter['Номер_накладной']
# C:\Users\Incognitus\AppData\Local\Temp\ipykernel_2652\665107074.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_pharmacy_filter['Сумма_счет-фактуры'] = df_total_pharmacy_filter['Сумма_НДС']
# ...

# %%
df_total_pharmacy_filter['Дата_счет-фактуры'] = pd.to_datetime(df_total_pharmacy_filter['Дата_счет-фактуры'], format="%d.%m.%Y")
# Out:
# C:\Users\Incognitus\AppData\Local\Temp\ipykernel_2652\3868325390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_pharmacy_filter['Дата_счет-фактуры'] = pd.to_datetime(df_total_pharmacy_filter['Дата_счет-фактуры'], format="%d.%m.%Y")

# %%
df_total_pharmacy_filter.head(3)
# Out:
#    №_п/п  Штрих-код_партии                                Наименование_товара  \
# 0      1      200200060311  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. Р.S №100 (50П...
# 1      2      200801594420  КОСМОПОР ПОВЯЗКА 10СМХ6СМ №25 П/ОПЕР. САМОКЛ. ...
# 2      3      200200075091  ХАРТМАНН БРАНОЛИНД H ПОВЯЗКА СТЕР. 10Х20СМ. №3...
#
#         Поставщик Дата_приходного_документа  Номер_приходного_документа  \
# 0  Катрен г.Химки                26.05.2021                   2002088.0
# 1     Здравсервис                25.03.2020                   9000479.8
# 2          Протек                01.09.2021                   2003451.0
#
#   Дата_накладной    Номер_накладной    Кол-во  \
# 0     25.05.2021         4665120-30  0.040000
# 1     25.03.2020  E7914339/27806739  0.040000
# 2     01.09.2021      164621235-001  0.066667
#
#    Сумма_в_закупочных_ценах_без_НДС Ставка_НДС_поставщика  Сумма_НДС  \
# 0                             33.65                   10%       3.37
# ...

# %%
pd.to_datetime?
# Out:
# Signature:
# pd.to_datetime(
#     arg: 'DatetimeScalarOrArrayConvertible | DictConvertible',
#     errors: 'DateTimeErrorChoices' = 'raise',
#     dayfirst: 'bool' = False,
#     yearfirst: 'bool' = False,
#     utc: 'bool' = False,
#     format: 'str | None' = None,
#     exact: 'bool | lib.NoDefault' = <no_default>,
#     unit: 'str | None' = None,
#     infer_datetime_format: 'lib.NoDefault | bool' = <no_default>,
#     origin: 'str' = 'unix',
#     cache: 'bool' = True,
# ) -> 'DatetimeIndex | Series | DatetimeScalar | NaTType | None'
# Docstring:
# Convert argument to datetime.
#
# This function converts a scalar, array-like, :class:`Series` or
# :class:`DataFrame`/dict-like to a pandas datetime object.
#
# Parameters
# ----------
# arg : int, float, str, datetime, list, tuple, 1-d array, Series, DataFrame/dict-like
#     The object to convert to a datetime. If a :class:`DataFrame` is provided, the
#     method expects minimally the following columns: :const:`"year"`,
# ...
