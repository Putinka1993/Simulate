# %% [markdown]
# # Метрики привлечения

# %% [markdown]
# # 📈 Метрики привлечения и стратегии рекламы
#
# ## 🎯 Основные стратегии показа рекламы
#
# **Охватная** — платим за показы (обычно за 1000 показов).
# Цель — максимальный охват аудитории.
#
# **Перформансная (Performance)** — платим за конкретный результат
# (клик, заявку, установку, покупку).
# Цель — получение конверсий.
#
# ---
#
# ## 💰 Базовые показатели
#
# - **Spent** — потраченный бюджет
# - **Impressions** — количество показов
# - **CPM (Cost per Mille)** — стоимость 1000 показов
#   - при фиксированной охватной стратегии задаётся в кабинете
#   - при перформансной: `CPM = Spent * 1000 / Impressions`
# - **Reach** — охваты (уникальные пользователи, увидевшие объявление)
#   - `Reach ≤ Impressions`
# - **Clicks** — количество кликов
# - **CPC (Cost per Click)** — стоимость клика
#   - при перформансной задаётся фиксировано
#   - при охватной: `CPC = Spent / Clicks`
# - **CTR (%) (Click Through Rate)** — кликабельность
#   - `CTR = Clicks / Impressions`
#
# ---
#
# ## 🧩 Целевые действия (Leads)
#
# После клика пользователь может совершить **целевое действие**:
#
# - Заявка (lead)
# - Установка (install)
# - Регистрация (registration)
#
# **Показатели:**
# - **CR1 (%)** — конверсия из кликов в лиды
#   `CR1 = Leads / Clicks`
# - **CPL / CPI / CPReg** — стоимость целевого действия
#   `CPL = Spent / Leads`
#   `CPI = Spent / Installs`
#   `CPReg = Spent / Registrations`
#
# ---
#
# ## ✅ Квалифицированные лиды (vLeads)
#
# **vLeads** — лиды, которые соответствуют внутренним критериям качества.
# Примеры:
# - Оставил заявку и действительно заинтересован
# - Зарегистрировался и пришёл на вебинар
# - Оставил заявку на дом и имеет подходящий бюджет
#
# **Показатели:**
# - **vCR (%)** — конверсия лида в квалифицированного
#   `vCR = vLeads / Leads`
# - **vCPL** — стоимость квалифицированного лида
#   `vCPL = Spent / vLeads`
#
# ---
#
# ## 💵 Покупки и доход
#
# - **Purchases** — количество покупок
# - **Revenue** — выручка
# - **CR2 (%)** — конверсия из квалифицированных лидов в покупку
#   `CR2 = Purchases / vLeads`
#   *(иногда считают от Leads)*
# - **CAC (Customer Acquisition Cost)** — стоимость привлечения клиента
#   `CAC = Spent / Purchases`
# - **ROMI (%) (Return of Marketing Investments)** — окупаемость маркетинга
#   `ROMI = (Revenue - Spent) / Spent`
#
# ---
#
# ## 🔁 Сквозные конверсии
#
# Можно считать конверсии между любыми этапами воронки:
#
# - Клик → Покупка
# - Лид → Покупка
# - Клик → Квалифицированный лид
