# %%
import pandas as pd

# %%
CODE_RUN = pd.read_csv(r'C:\Users\Incognitus\Documents\git_hub\Simulate\TRASH\itresume-coderun.csv', sep=',')

# %%
random_sampling = CODE_RUN.sample(n = 10000)
random_sampling
# Out:
#           id               created_at  problem_id  user_id  language_id
# 53061  53062  2022-05-06 17:19:53.198         169     1968            2
# 18960  18961  2022-01-31 15:25:47.256         147      411            2
# 21680  21681  2022-02-06 18:32:43.495         124     1178            2
# 43357  43358  2022-04-09 14:07:56.259         170     2611            2
# 29121  29122  2022-02-21 07:40:49.363          82     1818            2
# ...      ...                      ...         ...      ...          ...
# 42821  42822  2022-04-07 17:00:48.987          79     2647            2
# 3591    3592  2021-12-01 20:28:27.126         136      276            2
# 31211  31212  2022-02-26 15:25:16.531         169     2002            2
# 38503  38504  2022-03-26 13:56:22.922         151      422            2
# 20898  20899  2022-02-04 13:27:27.321          67     1012            2
#
# [10000 rows x 5 columns]
