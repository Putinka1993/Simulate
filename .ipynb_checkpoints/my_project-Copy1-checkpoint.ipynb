# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/vladislavlipkin/Downloads/data_work.xlsx', sheet_name = 'exportSD')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.columns
# Out:
# Index(['Дата/время регистрации', ' ', 'Номер', 'Статус', 'Приоритет',
#        'Получатель услуг', 'Инициатор', 'Расположение', 'Описание',
#        'Фактическое время выполнения', '     Услуга', '    Компонент услуги',
#        '   Вид запроса', 'Площадка обслуживания пользователя',
#        'Техническое описание', 'Головной запрос', '  Конфигурационные единицы',
#        'Текущий ответственный', 'Кем решен (сотрудник)',
#        'Кто выполняет контроль? (Сотрудник)', 'Плановое время выполнения',
#        'Просрочен', '     Результат работ', '     Описание решения',
#        'Количество уточнений', 'Количество возобновлений',
#        'Качество проведения работ по Запросу',
#        'Статус исполнения дочерних запросов', 'Крайний срок обработки',
#        'Крайний срок обработки ТО', 'Отложенный запрос',
#        'Время входа в статус'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    Дата/время регистрации                              Номер  Статус  \
# 0 2020-07-29 16:57:41.315  Запрос на обслуживание  RP2634178  Закрыт
#
#     Приоритет             Получатель услуг                    Инициатор  \
# 0  (4) Низкий  Парменов Сергей Анатольевич  Парменов Сергей Анатольевич
#
#   Расположение                                           Описание  \
# 0    ПАТЭС Спб  Обновление антивирусных баз Добрый день. Прошу...
#
#   Фактическое время выполнения  ...        Результат работ  \
# 0      2020-07-30 08:56:31.214  ...  Решение предоставлено
#
#                                     Описание решения Количество уточнений  \
# 0  Уважаемый Сергей Анатольевич! Ваша заявка была...                    0
#
#   Количество возобновлений Качество проведения работ по Запросу  \
# 0                        0                                    0
#
#   Статус исполнения дочерних запросов  Крайний срок обработки  \
# 0                                 NaN 2020-08-17 11:27:50.526
#
# ...

# %%
df.loc[:,['Дата/время регистрации', 'Крайний срок обработки', 'Фактическое время выполнения', 'Плановое время выполнения', 'Приоритет', 'Просрочен', '     Результат работ', 'Получатель услуг', 'Инициатор', 'Кем решен (сотрудник)', 'Расположение', 'Описание', '     Услуга', '    Компонент услуги', '   Вид запроса', 'Площадка обслуживания пользователя']].head(5)
# Out:
#    Дата/время регистрации  Крайний срок обработки  \
# 0 2020-07-29 16:57:41.315 2020-08-17 11:27:50.526
# 1 2020-09-03 17:12:25.514 2020-09-22 11:48:43.947
# 2 2020-12-24 11:10:54.874 2021-01-15 15:28:52.818
# 3 2021-02-12 15:05:12.186 2021-03-05 09:37:28.359
# 4 2021-02-11 08:40:34.669 2021-02-25 12:59:19.790
#
#   Фактическое время выполнения Плановое время выполнения   Приоритет  \
# 0      2020-07-30 08:56:31.214   2020-08-10 11:27:41.315  (4) Низкий
# 1      2020-09-04 10:37:38.608   2020-09-15 11:00:00.000  (4) Низкий
# 2      2020-12-24 16:23:14.968   2020-12-31 15:25:54.874  (4) Низкий
# 3      2021-02-12 15:23:53.645   2021-02-26 09:35:12.186  (4) Низкий
# 4      2021-02-15 11:15:40.259   2021-02-16 15:15:00.000  (4) Низкий
#
#       Просрочен        Результат работ                Получатель услуг  \
# 0  не просрочен  Решение предоставлено     Парменов Сергей Анатольевич
# 1  не просрочен  Решение предоставлено  Глушкова Наталья Александровна
# ...

# %%
for col_name in df.columns:
    print(col_name)
# Out:
# Дата/время регистрации
#
# Номер
# Статус
# Приоритет
# Получатель услуг
# Инициатор
# Расположение
# Описание
# Фактическое время выполнения
#      Услуга
#     Компонент услуги
#    Вид запроса
# Площадка обслуживания пользователя
# Техническое описание
# Головной запрос
#   Конфигурационные единицы
# Текущий ответственный
# Кем решен (сотрудник)
# Кто выполняет контроль? (Сотрудник)
# Плановое время выполнения
# Просрочен
#      Результат работ
#      Описание решения
# Количество уточнений
# Количество возобновлений
# Качество проведения работ по Запросу
# Статус исполнения дочерних запросов
# Крайний срок обработки
# Крайний срок обработки ТО
# Отложенный запрос
# Время входа в статус

# %%
df?
# Out:
# Type:        DataFrame
# String form:
# Дата/время регистрации                              Номер  \
#            0     2020-07-29 16:57:41.315 <...>                        NaN               NaN 2025-11-18 09:54:04.972
#
#            [18992 rows x 32 columns]
# Length:      18992
# File:        /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py
# Docstring:
# Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
# Data structure also contains labeled axes (rows and columns).
# Arithmetic operations align on both row and column labels. Can be
# thought of as a dict-like container for Series objects. The primary
# pandas data structure.
#
# Parameters
# ----------
# data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#     Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#     data is a dict, column order follows insertion-order. If a dict contains Series
# ...
