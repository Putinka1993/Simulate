# %% [markdown]
# ## 🐍 Python Drill: Практика для собеседований
#
# ### Добро пожаловать в ноутбук, собранный из реальных задач с технических интервью.
#
# ### Здесь ты отработаешь базовые конструкции Python, научишься работать со структурами данных, а также потрунируем алгоритмическое мышление.
#
# ---
#
# ## **Структура ноутбука**
#
# ### **1. Работа с циклами**
# `for`, `while`, поиск элементов, проверки условий, делители.
#
# ### **2. Списки (list) и кортежи (tuple)**
# Базовые операции, сортировки, срезы, list comprehensions.
#
# ### **3. Словари (dict) и множества (set)**
# Хранение данных, частотный анализ, уникальности, группировка.
#
# ### **4. Сортировки**
# `sorted()`, `list.sort()`, работа с ключами сортировки.
#
# ---
#
# Основная цель — дать тебе практику, ту что спрашивают на собеседованиях.

# %% [markdown]
# # 🧩 Стиль кода в Python (PEP 8): краткая база
#
# Этот блок поможет писать код так, как его оформляют в реальных компаниях.
# Мы разберём основные правила PEP 8, посмотрим правильные и неправильные примеры, и сформируем единый стиль для всех будущих задач.
#
# ---
#
# # 1. Именование переменных и функций
#
# ### Правильно
# - переменные: `snake_case`
# - функции: `snake_case`
# - классы: `CamelCase`
# - константы: `UPPER_CASE`
#
# ### Примеры
#
# **Хорошо:**
# ```python
# total_revenue = 1000
# def get_user_score(user_id):
#     ...
# class UserProfile:
#     ...
# MAX_RETRY_ATTEMPTS = 3
# ````
#
# **Плохо:**
#
# ```python
# TotalRevenue = 1000
# def GetUserScore():
#     ...
# class userprofile:
#     ...
# MaxRetryAttempts = 3
# ```
#
# ---
#
# # 2. Отступы и структура
#  Отступы между элементами
#
# ### Хорошо:
#
# ```python
# def calculate_price(amount, discount):
#     final = amount - discount
#     return final
# ```
#
# ### Плохо:
#
# ```python
# def calculate_price(amount,discount):
#   final=amount-discount
#   return final
# ```
#
# ---
#
# # 3. Пробелы — где нужны и где нет
#
# ### Нужны пробелы:
#
# * вокруг операторов: `=`, `+`, `-`, `==`
# * после запятых
#
# ### Хорошо:
#
# ```python
# x = a + b
# items = [1, 2, 3]
# ```
#
# ### Плохо:
#
# ```python
# x=a+b
# items=[1,2,3]
# ```
#
# ---
#
# # 4. Импорты
#
# * Сначала стандартная библиотека
# * Потом сторонние пакеты
# * Потом локальные модули
# * Каждая группа разделена пустой строкой
# * Импортируем только то, что реально используем
#
# ### Хорошо:
#
# ```python
# import os
# import sys
#
# import pandas as pd
# import numpy as np
#
# from utils.math import calc_distance
# ```
#
# ### Плохо:
#
# ```python
# import sys, os
# import numpy, pandas
# from utils.math import *
# ```
#
# ---
#
# # 5. Докстринги и комментарии
#
# ### Короткие пояснения — над строкой, не в конце
#
# **Хорошо:**
#
# ```python
# # фильтруем по активности
# active_users = df[df["is_active"] == 1]
# ```
#
# **Плохо:**
#
# ```python
# active_users = df[df["is_active"] == 1]  # фильтруем
# ```
#
# ### Докстринг внутри функции:
#
# ```python
# def get_price(amount, tax):
#     """
#     Считаем итоговую цену + учетом комиссии
#     """
#     return amount * (1 + tax)
# ```
#
# ---
#
# # 6. Стиль в словарях, списках, кортежах
#
# ### Хорошо:
#
# ```python
# user = {
#     "id": 10,
#     "name": "Alex",
#     "is_active": True,
# }
# ```
#
# ### Плохо:
#
# ```python
# user={"id":10,"name":"Alex","is_active":True}
# ```
#
# ---
#
# # 7. Исключения и ошибки
#
# * Выбрасываем конкретные ошибки
# * Пишем осмысленные сообщения
#
# ### Хорошо:
#
# ```python
# if amount < 0:
#     raise ValueError("amount must be non-negative")
# ```
#
# ### Плохо:
#
# ```python
# if amount<0:
#     raise Exception("error")
# ```
#
# ---
#
# ### Плохо:
#
# ```python
# import math
#
# def area_of_circle(r):
#     if r<0:
#         raise Exception("bad")
#     return math.pi*r*r
# print(area_of_circle(5))
# ```

# %% [markdown]
# ### Работа с циклами – базовые алгоритмы
#
# ### 1. Подсчитать количество положительных элементов
# На вход дан массив чисел `R`. Посчитай, сколько элементов строго больше нуля.
# **Вход:** `[-2, 5, 0, 7]`
# **Выход:** `2`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Заведи счетчик и увеличивай его при каждой встрече числа > 0.
# </details>
#
# ### 1.1 Найти границы элементов, превышающих X
# На вход подается массив `R` и число `X`. Верни индексы первого и последнего элементов, которые строго больше `X`. Если таких нет, верни `(-1, -1)`.
# **Вход:** `[1, 4, 7, 2, 9]`, `X = 3`
# **Выход:** `(1, 4)`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Проходи по массиву, фиксируя первый подходящий индекс и обновляя последний.
# </details>
#
# ### 2. Максимальная длина возрастающего отрезка
# На вход подается массив `R`. Найди длину самой длинной подпоследовательности подряд идущих элементов, которые строго возрастают.
# **Вход:** `[1, 2, 2, 3, 4]`
# **Выход:** `3`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Храни текущую длину возрастающего промежутка и максимум.
# </details>
#
# ### 3. Сумма квадратов до N
# На вход подается число `N`. Найди сумму квадратов чисел от 1 до `N` включительно.
# **Вход:** `4`
# **Выход:** `30`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Запусти цикл от 1 до `N` и добавляй `i * i` к ответу.
# </details>
#
# ### 4. Соседние пары с суммой X
# На вход подается массив `R` и число `X`. Подсчитай, сколько пар соседних элементов образуют сумму `X`.
# **Вход:** `[2, 5, 1, 4]`, `X = 6`
# **Выход:** `2`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Иди по массиву и проверяй каждую пару `(R[i], R[i+1])`.
# </details>
#
# ### 5. Число простых делителей
# На вход подается число `N`. Найди, сколько делителей `N` являются простыми числами.
# **Вход:** `28`
# **Выход:** `2`
# **Сложность:** `O(√N)`
# <details>
#   <summary>Подсказка</summary>
#   Перебирай делители и проверяй их простоту отдельной функцией.
# </details>
#
# ### 6. Целая часть кубического корня
# На вход подается число `N`. Найди целую часть его кубического корня.
# **Вход:** `30`
# **Выход:** `3`
# **Сложность:** `O(∛N)`
# <details>
#   <summary>Подсказка</summary>
#   Увеличивай кандидата, пока его куб не превысит `N`.
# </details>
#
# ### 7. Пара с максимальной разницей
# На вход подается массив `R`. Найди пару чисел с максимальной абсолютной разницей.
# **Вход:** `[3, -4, 2]`
# **Выход:** `(-4, 3)`
# **Сложность:** `O(N²)`
# <details>
#   <summary>Подсказка</summary>
#   Сравни все пары и обновляй лучшую по `abs(a - b)`.
# </details>
#
# ### 8. Пара с произведением X
# На вход подается массив `R` и число `X`. Найди пару элементов, произведение которых равно `X`.
# **Вход:** `[4, 1, 6, 2]`, `X = 8`
# **Выход:** `(4, 2)`
# **Сложность:** `O(N²)`
# <details>
#   <summary>Подсказка</summary>
#   Перебери все пары `i < j` и проверь их произведение.
# </details>
#
# ### 9. Произведение цифр числа
# На вход подается строка с числом. Найди произведение его цифр.
# **Вход:** `"305"`
# **Выход:** `0`
# **Сложность:** `O(len)`
# <details>
#   <summary>Подсказка</summary>
#   Преобразуй каждый символ в число и перемножай, начиная с `1`.
# </details>
#
# ### **10.1. Проверка на чередование символов (цикл)**
# Определи, чередуются ли символы строки `s`, то есть нет ли двух соседних одинаковых символов.
# **Вход:** `"abab"`
# **Выход:** `True`
# **Вход:** `"aaab"`
# **Выход:** `False`
# **Сложность:** `O(len)`
# <details>
#   <summary>Подсказка</summary>
#   Сравнивай `s[i]` и `s[i+1]` в одном проходе.
# </details>
#
# ### 10.2. Почти чередующаяся строка
# Определи, можно ли сделать строку `s` чередующейся, заменив не более одного символа.
# **Вход:** `"abac"`
# **Выход:** `True`
# **Сложность:** `O(len)`
# <details>
#   <summary>Подсказка</summary>
#   Посчитай количество нарушений чередования и убедись, что оно ≤ 1.
# </details>
#
# ### 11. Декодирование RLE
# На вход подается строка в формате RLE (`символ + количество`). Расшифруй ее.
# **Вход:** `"A2B3"`
# **Выход:** `"AABBB"`
# **Сложность:** `O(len * count)`
# <details>
#   <summary>Подсказка</summary>
#   Чередуй чтение символа и числа, добавляя `символ * число` в ответ.
# </details>
#
# ### **12. Циклический сдвиг числа вправо**
# На вход подается число `N`. Выполни циклический сдвиг его цифр вправо на один шаг.
# **Вход:** `1205`
# **Выход:** `5120`
# **Сложность:** `O(len)`
# <details>
#   <summary>Подсказка</summary>
#   Переведи в строку, возьми последний символ и перенеси его в начало.
# </details>
#
# ---
#
# ### **13. Проверка числа на степень тройки**
# На вход подается число `N`. Определи, является ли оно степенью тройки.
# **Вход:** `27`
# **Выход:** `True`
# **Вход:** `45`
# **Выход:** `False`
# **Сложность:** `O(log₃ N)`
# <details>
#   <summary>Подсказка</summary>
#   Делись на 3, пока остаток не появится или число не станет 1.
# </details>
#
# ---
#
# ### **14. Числа Трибоначчи (проверить, входит ли N)**
# На вход подается число `N`. Определи, встречается ли оно в последовательности Трибоначчи (`T₀=0, T₁=0, T₂=1`).
# **Вход:** `13`
# **Выход:** `True`
# **Вход:** `20`
# **Выход:** `False`
# **Сложность:** `O(k)`, где `k` — индекс числа
# <details>
#   <summary>Подсказка</summary>
#   Генерируй новые члены как сумму трёх предыдущих, пока не превысишь `N`.
# </details>
#
# ---
#
# ### **15. Количество шагов Коллатца**
# На вход подается число `N`. Подсчитай, сколько шагов последовательности Коллатца нужно, чтобы дойти до 1.
# **Вход:** `6`
# **Выход:** `8`
# **Сложность:** `O(steps)`
# <details>
#   <summary>Подсказка</summary>
#   Если `N` чётное, дели на 2, иначе умножай на 3 и прибавляй 1.
# </details>
#
# ---
#
# ### **16. Проверка числа Харшада**
# На вход подается число `N`. Определи, делится ли оно на сумму своих цифр.
# **Вход:** `18`
# **Выход:** `True`
# **Сложность:** `O(len)`
# <details>
#   <summary>Подсказка</summary>
#   Подсчитай сумму цифр и проверь `N % sum == 0`.
# </details>
#
# ---
#
# ### **17. Найти НОК двух чисел**
# На вход подаются `A` и `B`. Верни их наименьшее общее кратное.
# **Вход:** `12`, `18`
# **Выход:** `36`
# **Сложность:** `O(log min(A, B))`
# <details>
#   <summary>Подсказка</summary>
#   Сначала найди НОД и используй формулу `LCM = A * B / GCD`.
# </details>
#
# ---
#
# ### **18. Сумма чисел Фибоначчи до N**
# На вход подается число `N`. Найди сумму всех чисел Фибоначчи, которые не превосходят `N`.
# **Вход:** `10`
# **Выход:** `20`
# **Сложность:** `O(k)`
# <details>
#   <summary>Подсказка</summary>
#   Генерируй числа Фибоначчи `a, b = b, a + b` и добавляй их, пока `a <= N`.
# </details>
#
# ---
#
# ### **19. Количество смен знака в массиве**
# На вход подается массив `R`. Подсчитай, сколько раз знак соседних элементов меняется.
# **Вход:** `[-1, 3, -2, 4]`
# **Выход:** `3`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Сравнивай произведение соседей и проверяй, отрицательно ли оно.
# </details>
#
# ---
#
# ### **20. Геометрическая прогрессия до порога**
# Даны `a`, `r` и предел `P`. Подсчитай, сколько первых членов геометрической прогрессии `a * r^k` не превышают `P`.
# **Вход:** `a = 2`, `r = 3`, `P = 100`
# **Выход:** `4`
# **Сложность:** `O(log_r P)`
# <details>
#   <summary>Подсказка</summary>
#   Перемножай на `r`, пока значение не станет больше `P`.
# </details>

# %%
# 1. Подсчитать количество положительных элементов
nums = [-2, 5, 0, 7]
result = len(list(filter(lambda x: x > 0, nums)))
print(f'ответ на вопрос 1: {result}')

# 2. Максимальная длина возрастающего отрезка
subsequence = [1, 2, 2, 3, 4]

duration = 1
max_duration = 1

for i in range(1, len(subsequence)):
  if subsequence[i] > subsequence[i-1]:
    duration += 1
    max_duration = max(max_duration, duration)
  else:
    duration = 1

print(f'ответ на вопрос 2: {max_duration}')

# 3. Сумма квадратов до N
# На вход подается число N. Найди сумму квадратов чисел от 1 до N включительно.

in_N = 4
sum_of_squares = sum(list(map(lambda x: x*x, range(1, in_N+1))))

print(f'ответ на вопрос 3: {sum_of_squares}')

# 4. Соседние пары с суммой X
# На вход подается массив R и число X. Подсчитай, сколько пар соседних элементов образуют сумму X.
# Вход: [2, 5, 1, 4], X = 6
# Выход: 2
# Сложность: O(N)

arr1 = [2, 5, 1, 4]
X = 6
X_counter = 0
# изначально решал задачу видимо не только соседних чисел, так как удивил ваш ответ.
for i1 in range(0, len(arr1) - 1):
  for i2 in arr1[i1:]:
    if arr1[i1] + i2 == X:
      X_counter += 1

print(f'ответ на вопрос 4: {X_counter}')

X2_counter = 0
for i in range(len(arr1) - 1):
    if arr1[i] + arr1[i + 1] == X:
        X2_counter += 1

print(f'ответ на вопрос 4 (2 вариант задачи): {X2_counter}')
print('(если делать исключительно соседние не учитывая что можно посчитать с последнего соседнего числа до первого) получается что ваш ответ не правильный')

# 5. Число простых делителей
# На вход подается число N. Найди, сколько делителей N являются простыми числами.
# Вход: 28
# Выход: 2
# Сложность: O(√N)
N_simples = 28

def count_prime_divisors(n):
    if n <= 1:
        return 0

    count = 0
    num = n

    # Проверяем делитель 2 отдельно
    if num % 2 == 0:
        count += 1
        while num % 2 == 0:
            num //= 2

    # Проверяем нечётные делители до √n
    divisor = 3
    while divisor * divisor <= num:
        if num % divisor == 0:
            count += 1
            while num % divisor == 0:
                num //= divisor
        divisor += 2

    # Если осталось число > 1 — оно простое
    if num > 1:
        count += 1

    return count

print(f'ответ на вопрос 5: {count_prime_divisors(N_simples)} (не получилось самому решить)')

# 6. Целая часть кубического корня
# На вход подается число N. Найди целую часть его кубического корня.
# Вход: 30
# Выход: 3
# Сложность: O(∛N)

# неверно
count_cube = 30
the_integer_part_of_the_cube_root = max(list(filter(lambda x: x*x*x <= count_cube, range(1, int(count_cube ** (1/3)) + 2))))
print(f'ответ на вопрос 6: {the_integer_part_of_the_cube_root}')

# 7. Пара с максимальной разницей
# На вход подается массив `R`. Найди пару чисел с максимальной абсолютной разницей.  
# **Вход:** `[3, -4, 2]`  
# **Выход:** `(-4, 3)`  
# **Сложность:** `O(N²)` 

arr2 = [3, -4, 2]
max_diff = 0
pair = (0, 0)

for num in arr2:
   for num2 in arr2:
    diff = abs(num - num2)
    if diff > max_diff:
        max_diff = diff
        pair = (min(num, num2), max(num, num2))

print(f'ответ на вопрос 7: {pair}')

# 8. Пара с произведением X
# На вход подается массив `R` и число `X`. Найди пару элементов, произведение которых равно `X`.  
# **Вход:** `[4, 1, 6, 2]`, `X = 8`  
# **Выход:** `(4, 2)`  
# **Сложность:** `O(N²)` 

arr3 = [4, 1, 6, 2]
X3 = 8
pair_num = (0, 0)

for i1 in range(len(arr3)):
   for i2 in range(i1 + 1, len(arr3)):
      if arr3[i1] * arr3[i2] == X3:
         pair_num = (arr3[i1], arr3[i2])

print(f'ответ на вопрос 8: {pair_num}')

# 9. Произведение цифр числа
# На вход подается строка с числом. Найди произведение его цифр.  
# **Вход:** `"305"`  
# **Выход:** `0`  
# **Сложность:** `O(len)`

num_str = "305"
num_int = 1

for digit in num_str:
   if digit == '0':
      num_int = 0
      break
   else:
      num_int *= int(digit)

print(f'ответ на вопрос 9: {num_int}') 

# **10.1. Проверка на чередование символов (цикл)**
# Определи, чередуются ли символы строки `s`, то есть нет ли двух соседних одинаковых символов.  
# **Вход:** `"abab"`  
# **Выход:** `True`  
# **Вход:** `"aaab"`  
# **Выход:** `False`  
# **Сложность:** `O(len)`  

in_s = "abab"
result_in_s = True

for l in range(0, len(in_s) - 1):
   if in_s[l] == in_s[l + 1]:
      result_in_s = False
      break

print(f'ответ на вопрос 10.1: {result_in_s}')

# 10.2. Почти чередующаяся строка
# Определи, можно ли сделать строку `s` чередующейся, заменив не более одного символа.  
# **Вход:** `"abac"`  
# **Выход:** `True`  
# **Сложность:** `O(len)`

in_s2 = "abac"
result_in_s2 = False

for l in range(0, len(in_s2) - 2):
    if in_s2[l] == in_s2[l + 2]:
        result_in_s2 = False
    else:
        result_in_s2 = True
        
print(f'ответ на вопрос 10.2: {result_in_s2}')


# 11. Декодирование RLE
# На вход подается строка в формате RLE (`символ + количество`). Расшифруй ее.  
# **Вход:** `"A2B3"`  
# **Выход:** `"AABBB"`  
# **Сложность:** `O(len * count)`

in_rle = "A2B3"
result_str = ''

for sym in range(0, len(in_rle) - 1, 2):
    result_str += in_rle[sym] * int(in_rle[sym + 1])

print(f'ответ на вопрос 11: {result_str}')


# **12. Циклический сдвиг числа вправо**
# На вход подается число `N`. Выполни циклический сдвиг его цифр вправо на один шаг.  
# **Вход:** `1205`  
# **Выход:** `5120`  
# **Сложность:** `O(len)`

shift_step = 1
in_N2 = "1205"
result_in_N2 = in_N2[-shift_step:] + in_N2[:-shift_step]
print(f'ответ на вопрос 12: {result_in_N2}')


# **13. Проверка числа на степень тройки**
# На вход подается число `N`. Определи, является ли оно степенью тройки.  
# **Вход:** `27`  
# **Выход:** `True`  
# **Вход:** `45`  
# **Выход:** `False`  
# **Сложность:** `O(log₃ N)`

in_N3 = 27

def power_of_three(n):
    if n < 1:
        return False
    while n % 3 == 0:
        n //= 3
    return n == 1

print(f'ответ на вопрос 13: {power_of_three(in_N3)}')


# **14. Числа Трибоначчи (проверить, входит ли N)**
# На вход подается число `N`. Определи, встречается ли оно в последовательности Трибоначчи (`T₀=0, T₁=0, T₂=1`).  
# **Вход:** `13`  
# **Выход:** `True`  
# **Вход:** `20`  
# **Выход:** `False`  
# **Сложность:** `O(k)`, где `k` — индекс числа 

in_N4 = 20
result_in_N4 = False

if in_N4 == 0 or in_N4 == 1:
    result_in_N4 = True

a = 0
b = 0
c = 1

while c < in_N4:
    a, b, c = b, c, a + b + c
if c == in_N4:
    result_in_N4 = True

print(f'ответ на вопрос 14: {result_in_N4}')


# **15. Количество шагов Коллатца**
# На вход подается число `N`. Подсчитай, сколько шагов последовательности Коллатца нужно, чтобы дойти до 1.  
# **Вход:** `6`  
# **Выход:** `8`  
# **Сложность:** `O(steps)` 

in_N5 = 6
count_Collatz = 0

while in_N5 != 1:
   if
# Out:
# ответ на вопрос 1: 2
# ответ на вопрос 2: 3
# ответ на вопрос 3: 30
# ответ на вопрос 4: 2
# ответ на вопрос 4 (2 вариант задачи): 1
# (если делать исключительно соседние не учитывая что можно посчитать с последнего соседнего числа до первого) получается что ваш ответ не правильный
# ответ на вопрос 5: 2 (не получилось самому решить)
# ответ на вопрос 6: 3
# ответ на вопрос 7: (-4, 3)
# ответ на вопрос 8: (4, 2)
# ответ на вопрос 9: 0
# ответ на вопрос 10.1: True
# ответ на вопрос 10.2: True
# ответ на вопрос 11: AABBB
# ответ на вопрос 12: 5120
# ответ на вопрос 13: True
# ответ на вопрос 14: False

# %% [markdown]
# ## 2. Списки (list) + Кортежи (tuple) — базовые операции, list comprehensions.
# > **Кортежи редко спрашивают на собеседованиях. Они полезны для неизменяемых структур, но на практике их используют редко. Отличие от списка — кортеж неизменяемый. В реальной жизни почти всегда проще работать со списками.**
#
# ---
#
# ### **1. Заменить все отрицательные элементы нулями**
# На вход подается список чисел `R`. Замени каждый отрицательный элемент на `0`.
# **Вход:** `[3, -2, 5, -7]`
# **Выход:** `[3, 0, 5, 0]`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй list comprehension с условием `x if x >= 0 else 0`.
# </details>
#
# ---
#
# ### **2. Подсчитать количество уникальных элементов без set**
# На вход подается список `R`. Подсчитай, сколько различных значений он содержит, не используя множества.
# **Вход:** `[1, 2, 2, 3, 1]`
# **Выход:** `3`
# **Сложность:** `O(N²)` (при простом подходе)
# <details>
#   <summary>Подсказка</summary>
#   Храни вспомогательный список уникальных значений и добавляй туда элементы, если их ещё нет.
# </details>
#
# ---
#
# ### **3. Развернуть список вручную**
# На вход подается список `R`. Верни новый список в обратном порядке, не используя `reverse()` или `[::-1]`.
# **Вход:** `[1, 2, 3]`
# **Выход:** `[3, 2, 1]`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Пройдись по исходному списку с конца и добавляй элементы в новый.
# </details>
#
# ---
#
# ### **4. Удалить элементы на четных позициях**
# На вход подается список `R`. Удали элементы с индексами `0, 2, 4, ...`.
# **Вход:** `[10, 20, 30, 40, 50]`
# **Выход:** `[20, 40]`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй list comprehension с проверкой `i % 2 == 1` внутри `enumerate`.
# </details>
#
# ---
#
# ### **5. Разбить список на блоки длиной K**
# На вход подается список `R` и число `K`. Верни список блоков длиной `K` (последний блок может быть короче).
# **Вход:** `[1, 2, 3, 4, 5]`, `K = 2`
# **Выход:** `[[1, 2], [3, 4], [5]]`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй срезы `R[i:i+K]` в цикле по шагам `K`.
# </details>
#
# ---
#
# ### **6. Чередовать элементы двух списков**
# Даны списки `A` и `B`. Собери новый список, чередуя элементы: `A[0], B[0], A[1], B[1], ...`. Хвост более длинного списка добавь в конец.
# **Вход:** `[1, 2, 3]`, `['a', 'b']`
# **Выход:** `[1, 'a', 2, 'b', 3]`
# **Сложность:** `O(len(A) + len(B))`
# <details>
#   <summary>Подсказка</summary>
#   Итерация по индексу `i` и проверки наличия элемента в каждом списке.
# </details>
#
# ---
#
# ### **7. Кубы чисел, кратных 3**
# На вход подается список `R`. Верни список кубов чисел, делящихся на 3.
# **Вход:** `[3, 4, 6, 7]`
# **Выход:** `[27, 216]`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй list comprehension с проверкой `x % 3 == 0`.
# </details>
#
# ---
#
# На вход подается список строк `S` и окончание `suffix`. Оставь только строки, заканчивающиеся на `suffix`.
# ### **8. Фильтр строк по суффиксу**
# **Вход:** `['data.py', 'main.js', 'test.py']`, `suffix = '.py'`
# **Выход:** `['data.py', 'test.py']`
# **Сложность:** `O(Σ len)`
# <details>
#   <summary>Подсказка</summary>
#   Используй `str.endswith` внутри list comprehension.
# </details>
#
# ---
#
# ### **9. Сумма по строкам матрицы**
# На вход подается матрица `M`. Верни список сумм каждой строки.
# **Вход:** `[[1, 2], [3, 4], [5, 6]]`
# **Выход:** `[3, 7, 11]`
# **Сложность:** `O(R*C)`
# <details>
#   <summary>Подсказка</summary>
#   Используй list comprehension с `sum(row)`.
# </details>
#
# ---
#
# ### **10. Проверить, упорядочен ли список по невозрастанию**
# На вход подается список `R`. Верни `True`, если каждый следующий элемент не больше предыдущего.
# **Вход:** `[9, 7, 7, 3]`
# **Выход:** `True`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Сравнивай `R[i]` и `R[i+1]` в цикле.
# </details>
#
# ---
#
# ### **11. Сгенерировать список степеней тройки**
# На вход подается число `N`. Верни список `[3**0, 3**1, ..., 3**(N-1)]`.
# **Вход:** `N = 4`
# **Выход:** `[1, 3, 9, 27]`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй list comprehension и оператор возведения в степень.
# </details>
#
# ---
#
# ### **12. Удалить каждый второй элемент, используя del**
# На вход подается список `R`. С помощью `del` удали элементы с индексами `1, 3, 5, ...`.
# **Вход:** `[0, 1, 2, 3, 4, 5]`
# **Выход:** `[0, 2, 4]`
# **Сложность:** `O(N²)` (из-за сдвигов)
# <details>
#   <summary>Подсказка</summary>
#   Удаляй элементы в обратном порядке, чтобы не нарушать индексы.
# </details>
#
# ---
#
# ### **13. Собрать элементы правой половины через enumerate**
# На вход подается список `R`. Верни новый список, в который попадут элементы с индексами ≥ `len(R)//2`, используя `enumerate()`.
# **Вход:** `[1, 2, 3, 4, 5, 6]`
# **Выход:** `[4, 5, 6]`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Фильтруй пары `(i, value)` по условию на индекс.
# </details>
#
# ---
#
# ### **14. Проверка списка на палиндром (срез)**
# На вход подается список `R`. Определи, является ли он палиндромом.
# **Вход:** `[1, 2, 3, 2, 1]`
# **Выход:** `True`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Сравни `R` и `R[::-1]`.
# </details>
#
# ---
#
# ### **15. Индексы минимального элемента**
# На вход подается список `R`. Верни список индексов, где встречается минимальное значение.
# **Вход:** `[2, 1, 3, 1]`
# **Выход:** `[1, 3]`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Найди минимум, затем пройдись по списку с `enumerate`.
# </details>
#
# ---
#
# ### **16. Разделить список на числа меньше и не меньше среднего**
# На вход подается список `R`. Верни кортеж из двух списков: первый содержит элементы < среднего, второй — остальные.
# **Вход:** `[1, 2, 3, 4, 5]`
# **Выход:** `([1, 2], [3, 4, 5])`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Сначала найди среднее, потом два list comprehension.
# </details>
#
# ---
#
# ### **17. Удалить повторяющиеся элементы, сохранив порядок**
# На вход подается список `R`. Удали дубликаты, оставив первое вхождение каждого элемента.
# **Вход:** `[1, 2, 1, 3, 2]`
# **Выход:** `[1, 2, 3]`
# **Сложность:** `O(N²)` без множеств
# <details>
#   <summary>Подсказка</summary>
#   Заведи список `seen` и добавляй элемент, только если его там нет.
# </details>
#
# ---
#
# ### **18. Развернуть каждый второй подсписок матрицы**
# На вход подается матрица `M`. Разверни списки с нечётным индексом.
# **Вход:** `[[1, 2], [3, 4], [5, 6]]`
# **Выход:** `[[1, 2], [4, 3], [5, 6]]`
# **Сложность:** `O(R*C)`
# <details>
#   <summary>Подсказка</summary>
#   Используй `enumerate` и срез `row[::-1]` на нужных строках.
# </details>
#
# ---
#
# ### **19. Список пар (элемент, следующий элемент)**
# На вход подается список `R`. Верни список кортежей `(R[i], R[i+1])`. Последний элемент без пары игнорируй.
# **Вход:** `[5, 6, 7]`
# **Выход:** `[(5, 6), (6, 7)]`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Иди по индексам до `len(R) - 1`.
# </details>
#
# ---
#
# ### **20. Проверить, пересекаются ли два списка (без set)**
# На вход подаются списки `A` и `B`. Верни `True`, если есть общий элемент.
# **Вход:** `[1, 4]`, `[2, 4, 6]`
# **Выход:** `True`
# **Сложность:** `O(len(A)*len(B))`
# <details>
#   <summary>Подсказка</summary>
#   Вложенные циклы или проверка каждого `a` в `B` методом `in`.
# </details>
#
# ---
#
# ### **21. Сдвиг списка влево на K позиций**
# На вход подается список `R` и число `K`. Верни новый список, сдвинутый влево на `K` позиций.
# **Вход:** `[1, 2, 3, 4, 5]`, `K = 2`
# **Выход:** `[3, 4, 5, 1, 2]`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй срезы `R[K:] + R[:K]`.
# </details>

# %%
# Вставь свое решение тут

# %% [markdown]
# ## 3. Словари (dict) + Множества (set)
# > **Словари хранят пары "ключ:значение" с быстрым доступом `O(1)`. Множества используются для хранения уникальных элементов и быстрого поиска.
# > В задачах мы итерируемся по списку и строим dict/set или фильтруем их.**
#
# ---
#
# ### **22. Сгруппировать строки по длине**
# На вход подается список слов `words`. Верни словарь вида `{длина: [слова этой длины]}`.
# **Вход:** `['me', 'cat', 'hi', 'cloud']`
# **Выход:** `{2: ['me', 'hi'], 3: ['cat'], 5: ['cloud']}`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй `defaultdict(list)` или проверку наличия ключа перед добавлением.
# </details>
#
# ---
#
# ### **23. Множество символов без пробелов**
# На вход подается строка `s`. Верни множество всех символов, кроме пробелов.
# **Вход:** `'data science'`
# **Выход:** `{'d', 'a', 't', 's', 'c', 'i', 'e', 'n'}`
# **Сложность:** `O(len)`
# <details>
#   <summary>Подсказка</summary>
#   Удали пробелы методом `replace()` и применяй `set`.
# </details>
#
# ---
#
# ### **24. Словарь позиций слова**
# На вход подается список слов `words`. Построй словарь `{word: [индексы в списке]}`.
# **Вход:** `['a', 'b', 'a', 'c']`
# **Выход:** `{'a': [0, 2], 'b': [1], 'c': [3]}`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй `enumerate` и добавляй индекс в список по ключу.
# </details>
#
# ---
#
# ### **25. Найти ключ с самым длинным списком значений**
# На вход подается словарь `groups`, где значения — списки. Верни ключ, у которого список длиннее всех.
# **Вход:** `{'a': [1], 'b': [2, 3], 'c': [4, 5, 6]}`
# **Выход:** `'c'`
# **Сложность:** `O(K)`
# <details>
#   <summary>Подсказка</summary>
#   Сравни длины списков через `max(groups, key=lambda k: len(groups[k]))`.
# </details>
#
# ---
#
# ### **26. Проверка пересечения множеств**
# На вход подаются множества `A` и `B`. Верни `True`, если они имеют общие элементы.
# **Вход:** `{1, 2}`, `{3, 4}`
# **Выход:** `False`
# **Сложность:** `O(min(len(A), len(B)))`
# <details>
#   <summary>Подсказка</summary>
#   Используй оператор `isdisjoint`.
# </details>
#
# ---
#
# ### **27. Симметрическая разность как отсортированный список**
# Даны множества `A` и `B`. Верни отсортированный список элементов, которые есть ровно в одном из них.
# **Вход:** `{1, 4, 6}`, `{2, 4, 7}`
# **Выход:** `[1, 2, 6, 7]`
# **Сложность:** `O((|A|+|B|) log |A∪B|)`
# <details>
#   <summary>Подсказка</summary>
#   Вычисли `A ^ B`, затем применяй `sorted`.
# </details>
#
# ---
#
# ### **28. Очистить словарь от значений None**
# На вход подается словарь `config`. Удали пары, где значение равно `None`.
# **Вход:** `{'host': 'db', 'port': None, 'user': 'admin'}`
# **Выход:** `{'host': 'db', 'user': 'admin'}`
# **Сложность:** `O(K)`
# <details>
#   <summary>Подсказка</summary>
#   Используй словарное включение с условием `if v is not None`.
# </details>
#
# ---
#
# ### **29. Сгруппировать e-mail по домену**
# Дан список адресов. Верни словарь `{домен: [адреса]}`.
# **Вход:** `['a@mail.ru', 'b@gmail.com', 'c@mail.ru']`
# **Выход:** `{'mail.ru': ['a@mail.ru', 'c@mail.ru'], 'gmail.com': ['b@gmail.com']}`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Разделяй строку по `'@'` и добавляй в список по домену.
# </details>
#
# ---
#
# ### **30. Словарь сумм цифр**
# На вход подается список чисел `nums`. Верни словарь `{num: сумма его цифр}`.
# **Вход:** `[12, 305, 8]`
# **Выход:** `{12: 3, 305: 8, 8: 8}`
# **Сложность:** `O(Σ len(num))`
# <details>
#   <summary>Подсказка</summary>
#   Преобразуй число в строку и просуммируй `int(ch)`.
# </details>
#
# ---
#
# ### **31. Все ключи с минимальным значением**
# На вход подается словарь `prices`. Верни список всех ключей, чьё значение минимально.
# **Вход:** `{'apple': 50, 'banana': 30, 'pear': 30}`
# **Выход:** `['banana', 'pear']`
# **Сложность:** `O(K)`
# <details>
#   <summary>Подсказка</summary>
#   Сначала найди минимальное значение, затем отфильтруй ключи.
# </details>
#
# ---
#
# ### **32. Фильтр словаря по длине ключа**
# На вход подается словарь `grades` и число `L`. Верни только те пары, где длина имени ≥ `L`.
# **Вход:** `{'Al': 90, 'Maria': 85, 'Bob': 70}`, `L = 4`
# **Выход:** `{'Maria': 85}`
# **Сложность:** `O(K)`
# <details>
#   <summary>Подсказка</summary>
#   Используй словарное включение и `len(name) >= L`.
# </details>
#
# ---
#
# ### **33. Студенты выше среднего**
# На вход подается словарь `grades`. Верни список студентов, чья оценка строго выше среднего по группе.
# **Вход:** `{'Ann': 90, 'Bob': 70, 'Cara': 80}`
# **Выход:** `['Ann']`
# **Сложность:** `O(K)`
# <details>
#   <summary>Подсказка</summary>
#   Найди среднее `sum(values)/len(values)` и фильтруй ключи.
# </details>
#
# ---
#
# ### **34. Инвертировать словарь списков**
# На вход подается словарь `d`, где значения — списки. Создай словарь `{элемент списка: [ключи, в которых он встречается]}`.
# **Вход:** `{'a': [1, 2], 'b': [2]}`
# **Выход:** `{1: ['a'], 2: ['a', 'b']}`
# **Сложность:** `O(Σ длина списков)`
# <details>
#   <summary>Подсказка</summary>
#   Иди по парам `(key, values)` и добавляй ключ в список по каждому элементу.
# </details>
#
# ---
#
# ### **35. Объединить словари, собирая значения в списки**
# Даны два словаря `d1` и `d2`. Верни словарь, где значения — списки всех найденных значений по ключу.
# **Вход:** `{'a': 1, 'b': 2}`, `{'b': 3, 'c': 4}`
# **Выход:** `{'a': [1], 'b': [2, 3], 'c': [4]}`
# **Сложность:** `O(|d1| + |d2|)`
# <details>
#   <summary>Подсказка</summary>
#   Проходи по объединению ключей и собирай `d1.get(k)` и `d2.get(k)` в список.
# </details>
#
# ---
#
# ### **36. Множество букв из списка слов**
# На вход подается список строк `words`. Верни множество всех букв, встречающихся в списке.
# **Вход:** `['hi', 'python']`
# **Выход:** `{'h', 'i', 'p', 'y', 't', 'o', 'n'}`
# **Сложность:** `O(Σ len)`
# <details>
#   <summary>Подсказка</summary>
#   Инициализируй пустое множество и добавляй символы каждого слова.
# </details>
#
# ---
#
# ### **37. Проверить, что A — строгое супермножество B**
# Даны множества `A` и `B`. Верни `True`, если `A` содержит все элементы `B` и имеет хотя бы один элемент сверх этого.
# **Вход:** `{1, 2, 3}`, `{1, 2}`
# **Выход:** `True`
# **Сложность:** `O(len(B))`
# <details>
#   <summary>Подсказка</summary>
#   Используй `B < A`.
# </details>
#
# ---
#
# ### **38. Элементы, встречающиеся хотя бы в двух из трёх множеств**
# На вход подаются множества `A`, `B`, `C`. Верни множество элементов, которые входят минимум в два множества.
# **Вход:** `{1, 2}`, `{2, 3}`, `{2, 4}`
# **Выход:** `{2}`
# **Сложность:** `O(|A| + |B| + |C|)`
# <details>
#   <summary>Подсказка</summary>
#   Используй суммы пересечений: `(A & B) | (A & C) | (B & C)`.
# </details>
#
# ---
#
# ### **39. Количество различных значений словаря**
# На вход подается словарь `d`. Верни число уникальных значений.
# **Вход:** `{'a': 1, 'b': 2, 'c': 1}`
# **Выход:** `2`
# **Сложность:** `O(K)`
# <details>
#   <summary>Подсказка</summary>
#   Построй `set(d.values())` и возьми длину.
# </details>
#
# ---
#
# ### **40. Словарь квадратов только для нечётных чисел**
# На вход подается список `nums`. Верни `{num: num**2}` только для нечётных `num`.
# **Вход:** `[1, 2, 3, 4]`
# **Выход:** `{1: 1, 3: 9}`
# **Сложность:** `O(N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй словарное включение с условием `if num % 2 == 1`.
# </details>

# %%
# Вставь свое решение тут

# %% [markdown]
# ## 4. Задачи на сортировку
#
#
# ### **41. Волновая перестановка**
# Отсортируй массив, затем переставь элементы так, чтобы получился шаблон `a0 <= a1 >= a2 <= a3 ...`.
# **Вход:** `[3, 6, 5, 10, 7]`
# **Выход:** `[3, 6, 5, 10, 7]` (один из вариантов)
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   После сортировки меняй местами пары `(i, i+1)`.
# </details>
#
# ---
#
# ### **42. Сумма N минимальных элементов**
# Отсортируй список и найди сумму `N` самых маленьких значений.
# **Вход:** `[8, 4, 6, 1]`, `N = 2`
# **Выход:** `5`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   После сортировки возьми срез `[:N]` и просуммируй.
# </details>
#
# ---
#
# ### **43. Сортировка строк по числу гласных**
# Отсортируй список слов по убыванию количества гласных; при равенстве — по алфавиту.
# **Вход:** `['pear', 'banana', 'apple']`
# **Выход:** `['banana', 'apple', 'pear']`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   В передаваемом `key` возвращай `(-count_vowels(word), word)`.
# </details>
#
# ---
#
# ### **44. Сортировка списка кортежей (город, температура)**
# Отсортируй кортежи по температуре по убыванию, при равенстве — по названию города.
# **Вход:** `[('Moscow', 5), ('Berlin', 10), ('Minsk', 5)]`
# **Выход:** `[('Berlin', 10), ('Minsk', 5), ('Moscow', 5)]`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй `key=lambda x: (-x[1], x[0])`.
# </details>
#
# ---
#
# ### **45. Сортировка чисел по сумме цифр**
# Отсортируй числа по сумме их цифр; при равенстве — по самому числу.
# **Вход:** `[10, 2, 11, 20]`
# **Выход:** `[2, 10, 11, 20]`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   В `key` верни кортеж `(sum_digits(x), x)`.
# </details>
#
# ---
#
# ### **46. Сортировка слов по последней букве**
# Отсортируй список строк по их последнему символу.
# **Вход:** `['cab', 'dog', 'apple']`
# **Выход:** `['apple', 'cab', 'dog']`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй `key=lambda w: w[-1]`.
# </details>
#
# ---
#
# ### **47. Сортировка списка словарей по полю priority**
# Дан список словарей `{'task': str, 'priority': int}`. Отсортируй по `priority` по возрастанию.
# **Вход:** `[{'task': 'A', 'priority': 2}, {'task': 'B', 'priority': 1}]`
# **Выход:** `[{'task': 'B', 'priority': 1}, {'task': 'A', 'priority': 2}]`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй `key=lambda item: item['priority']`.
# </details>
#
# ---
#
# ### **48. Сортировка дат ISO-формата**
# Дан список строк `YYYY-MM-DD`. Отсортируй их по возрастанию даты.
# **Вход:** `['2023-12-01', '2022-01-10', '2023-01-01']`
# **Выход:** `['2022-01-10', '2023-01-01', '2023-12-01']`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   Строки уже сравниваются лексикографически корректно в ISO-формате.
# </details>
#
# ---
#
# ### **49. Сортировка интервалов по длине**
# Дан список интервалов `(start, end)`. Отсортируй по длине интервала, при равенстве — по `start`.
# **Вход:** `[(0, 5), (1, 2), (2, 6)]`
# **Выход:** `[(1, 2), (0, 5), (2, 6)]`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй ключ `(interval[1] - interval[0], interval[0])`.
# </details>
#
# ---
#
# ### **50. Сортировка чисел по расстоянию до X**
# Даны `nums` и число `X`. Отсортируй `nums` по возрастанию `abs(num - X)`.
# **Вход:** `[7, 1, 5, 10]`, `X = 6`
# **Выход:** `[5, 7, 10, 1]`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   Ключ: `key=lambda num: (abs(num - X), num)`.
# </details>
#
# ---
#
# ### **51. Сгруппировать одинаковые элементы после сортировки**
# Отсортируй список и верни список кортежей `(значение, количество)` в порядке возрастания значений.
# **Вход:** `[3, 1, 3, 2]`
# **Выход:** `[(1, 1), (2, 1), (3, 2)]`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   После сортировки проходи по списку, считая длину текущего блока.
# </details>
#
# ---
#
# ### **52. Сортировка списков по сумме элементов**
# Дан список списков. Отсортируй их по сумме элементов, при равенстве — по длине списка.
# **Вход:** `[[1, 2], [3], [1, 1, 1]]`
# **Выход:** `[[3], [1, 2], [1, 1, 1]]`
# **Сложность:** `O(N log N)`
# <details>
#   <summary>Подсказка</summary>
#   Используй ключ `(sum(sub), len(sub))`.
# </details>

# %%
# Вставь свое решение тут
