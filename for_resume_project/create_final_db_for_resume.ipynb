# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Incognitus\Documents\git_hub\Simulate\for_resume_project\support_tickets_final_anonymized.csv')

# %%
df.head(3)
# Out:
#     Дата/время регистрации   Крайний срок обработки  \
# 0  2020-07-29 16:57:41.315  2020-08-17 11:27:50.526
# 1  2020-09-03 17:12:25.514  2020-09-22 11:48:43.947
# 2  2020-12-24 11:10:54.874  2021-01-15 15:28:52.818
#
#   Фактическое время выполнения Плановое время выполнения   Приоритет  \
# 0      2020-07-30 08:56:31.214   2020-08-10 11:27:41.315  (4) Низкий
# 1      2020-09-04 10:37:38.608   2020-09-15 11:00:00.000  (4) Низкий
# 2      2020-12-24 16:23:14.968   2020-12-31 15:25:54.874  (4) Низкий
#
#       Просрочен        Результат работ Получатель услуг      Инициатор  \
# 0  не просрочен  Решение предоставлено    User_5690b13b  User_5690b13b
# 1  не просрочен  Решение предоставлено    User_9d645efd  User_9d645efd
# 2  не просрочен  Решение предоставлено    User_7b6353d9  User_2e984f36
#
#   Кем решен (сотрудник)       Расположение  \
# 0         User_27e54663   АЭС-1 (Северная)
# 1         User_c79cd486   АЭС-2 (Западная)
# 2         User_2e984f36  АЭС-3 (Восточная)
#
#                                             Описание  \
# 0  Добрый день! синий экран при запуске. Ошибка: ...
# 1  Добрый день! прошу установить СЭД на компьютер...
# 2  Добрый день! зависает 1С:Предприятие при работ...
#
#                        Услуга                   Вид запроса
# 0  Рабочая станция (стандарт)  4. Настройка / обновление ПО
# 1  Рабочая станция (стандарт)        Запрос на обслуживание
# 2  Рабочая станция (стандарт)     Настройка / обновление ПО

# %%
# расположение
df['Расположение'].unique()
# Out:
# array(['АЭС-1 (Северная)', 'АЭС-2 (Западная)', 'АЭС-3 (Восточная)',
#        'АЭС-4 (Южная)', 'АЭС-5 (Центральная)', 'АЭС-6 (Прибрежная)',
#        'Промплощадка Альфа', 'Промплощадка Бета',
#        'Хранилище отработанного топлива №1',
#        'Хранилище отработанного топлива №2', 'Учебно-тренировочный центр',
#        'Лабораторный корпус', 'Административно-бытовой корпус',
#        'Здание управления (ЗУ-1)', 'Здание управления (ЗУ-2)',
#        'Резервный пункт управления', 'Складское хозяйство',
#        'Турбинный цех'], dtype=object)

# %%
# расположение
df['Услуга'].unique()
# Out:
# array(['Рабочая станция (стандарт)', 'Рабочая станция (КЦ)',
#        'Учетные записи (AD)', 'Сетевое оборудование (пассивное)',
#        'Оргтехника (принтеры/МФУ)', 'СЗИ (антивирусы/шифрование)',
#        'Доступ в интернет (сетевое)',
#        'Система отображения (табло/мониторы)', 'Специализированные СЗИ',
#        'Рабочая станция (повышенной защищенности)',
#        'Сетевое оборудование (активное)', 'Видео-конференц-связь', 'СЭД',
#        'Файловые ресурсы и доступы', 'Внешние ИТ-услуги',
#        'Корпоративная почта', 'Инженерные САПР', 'Серверное ПО',
#        'Строительные информационные системы', 'Тонкий клиент / VDI',
#        'Услуги ОИКТ', 'BI-системы', 'Рабочая станция оператора',
#        'Банковские информационные системы', 'Система видеонаблюдения',
#        'Система безопасности СИРИУС', 'Цифровая платформа',
#        'Диспетчерские системы', 'СКУД и электроснабжение',
#        'Серверная инфраструктура', 'Система единого времени',
#        'НСИ и справочники', 'Сбытовые информационные системы',
#        'Корпоративный портал', 'Учет ИТ-активов',
#        'Проектная деятельность', 'Система мониторинга серверов',
#        'ИТ-услуга (Управление конфигурациями (CMDB))',
#        'Финансовые системы', 'Системы оповещения', 'Отчетные системы',
#        'Внутренние работы', 'IP-телефония'], dtype=object)

# %%
# вид запроса 
df['Вид запроса'].unique()
# Out:
# array(['4. Настройка / обновление ПО', 'Запрос на обслуживание',
#        'Настройка / обновление ПО', 'Техническое обслуживание ПК',
#        'Настройка клиента электронной почты',
#        '5. Установка / переустановка Windows',
#        'Установка драйвера принтера, сканера, МФУ',
#        'Перенастройка ПК на нового пользователя',
#        '2. Установка дополнительного программного обеспечения',
#        '1. Установка стандартного программного обеспечения',
#        'Запрос на обслуживание (ИТ-6 ИТ-Поддержка процессов ИБ)',
#        'Обслуживание  дополнительного программного обеспечения',
#        'Установить / подключить ПК на рабочем месте пользователя',
#        'Установка дополнительного программного обеспечения',
#        'Установка стандартного программного обеспечения',
#        'Замена / заправка картриджа',
#        '3. Установка драйвера принтера, сканера, МФУ',
#        'Доступ к папке (сетевому ресурсу)',
#        'Доступ в группу Active Directory (предоставление / изменение / блокировка)',
#        'Запрос на обслуживание_',
#        'Копирование данных (ПК / Сеть / Интернет)', 'Консультация',
#        'Консультирование пользователя Заказчика по работе в системе удаленного доступа',
#        'Установка стандартного ПО',
#        'Корректировка данных пользователя в AD',
#        'Настройка АРМ для удаленной работы (Композитный запрос)',
#        'Первичная классификация', 'Установка ИС на АРМ',
#        'Настройка АРМ для удаленной работы ЛенАЭС',
#        'Регистрация в ЛВС нового пользователя',
#        'Доступ (предоставление | изменение | блокировка)',
#        'Поддержка и настройка АРМ VDI', 'Актуализация реестра ОО',
#        'Входной контроль ПК', 'Обслуживание АРМ',
#        'Повторная классификация',
#        'Установить / подключить ПК на рабочем месте',
#        'Обновление и изменение КЕ', 'Полугодовое ТО',
#        'Предоставление удаленного доступа VDI (композит)',
#        'Заявка к расходному договору', 'Запрос на изменение'],
#       dtype=object)
